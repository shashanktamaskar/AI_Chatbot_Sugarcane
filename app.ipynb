# %%
pip install google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-genai
#   Downloading google_genai-1.51.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (2.39.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (2.11.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (9.1.2)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /home/karan/.local/lib/python3.12/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/karan/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/karan/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/karan/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/karan/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/karan/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /home/karan/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/karan/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/karan/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/karan/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/karan/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/karan/.local/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/karan/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/karan/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/karan/.local/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Downloading google_genai-1.51.0-py3-none-any.whl (260 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Installing collected packages: websockets, google-genai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [google-genai] [google-genai]
# Successfully installed google-genai-1.51.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types
import time

client = genai.Client(api_key="AIzaSyD2Q06JwF6ZytV2EpF8v6a1_OrQS8HNbqA")
store = client.file_search_stores.create()

upload_op = client.file_search_stores.upload_to_file_search_store(
    file_search_store_name=store.name,
    file='guide.pdf'
)

while not upload_op.done:
  time.sleep(5)
  upload_op = client.operations.get(upload_op)

# Use the file search store as a tool in your generation call
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='What does the research say about how can i easily fix my car if it has a electricall loss on the lights?',
    config=types.GenerateContentConfig(
        tools=[types.Tool(
            file_search=types.FileSearch(
                file_search_store_names=[store.name]
            )
        )]
    )
)
print(response.text)

# Support your response with links to the grounding sources.
grounding = response.candidates[0].grounding_metadata
if not grounding:
 print('No grounding sources found')
else:
 sources = {c.retrieved_context.title for c in grounding.grounding_chunks}
 print('Sources:', *sources)
# Out:
# Modern cars are equipped with numerous microprocessors that control various functions, including interior lighting, and these systems are far more complex than older vehicles. This complexity means that identifying the source of an electrical problem, such as a loss of power to the lights, can be challenging and time-consuming, even for experienced technicians using diagnostic tools.
#
# While the provided research doesn't offer specific steps for a do-it-yourself fix for electrical loss on car lights, it does highlight that electrical issues, in particular, can have diagnosis costs that exceed the actual repair cost. This is because significant time may be spent tracing an open circuit in a wire, for instance, before a relatively simple fix can be applied.
#
# When dealing with car problems, especially electrical ones, it's recommended to share any concerns with a service advisor, service your vehicle according to the manufacturer's schedule, and always insist on a written estimate before any work begins.
# Sources: guide.pdf
